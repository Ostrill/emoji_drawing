# %% [markdown]
# # Облегченная версия для простого рисования

# %%
# Импорт функции, которая сделает все сама
from lite_utils import draw

# %%
# %%time

img = draw(image_filename='frog.png',
     save_image_name='frog2',
     emoji_width=50,
     emoji_resolution=50,
     background_color=(0, 0, 0),
     # emojis=None, 
     emoji_dict_name='flags_black', 
     disp=True)
# Out:
# Исходная картинка: 1080x1080
# Из смайликов:      50x50
# Рисование:  100.0%
# Изображение в виде текста сохранено
# Сохранение изображения:  100.0%
# Изображение в png-формате сохранено
# CPU times: user 7.8 s, sys: 408 ms, total: 8.21 s
# Wall time: 18.6 s
