# %% [markdown]
# # Облегченная версия для простого рисования

# %%
# Функция, которая сделает все сама
from lite_utils import draw

# %% [markdown]
# ### Параметры для рисования:
# - **image_filename** - имя файла, лежащего в папке `input/`, который нужно нарисовать смайликами;
# - **save_image_name** - название, под которым итоговая картинка сохранится в папку `output/` в форматах *.txt* и *.png*;
# - **emoji_width** - сколько смайликов в ширину будет итоговая картинка;
# - **emoji_resolution** - длина стороны квадрата для отрисовки смайлика (в пикселях). Чем больше, тем качественнее получится картинка, но и тем больше потратится времени на ее создание;
# - **background_color** - цвет фона изображения в формате RGB;
# - **emojis**:
#     - либо строка, состоящая из смайликов (написанных через пробел), из которых нужно нарисовать картинку,
#     - либо *None*, тогда необходимо указать один из имеющихся словарей смайликов в параметр **emoji_dict_name**;
# - **emoji_dict_name** - название словаря из папки `emoji_dicts/`. Не учитывается, если задана строка из смайликов в параметре **emojis**. Для каждой группы смайликов есть две темы - *black* и *white* для отрисовки на черном и белом фоне соответственно. Каждый словарь называется следующим образом: `<группа>_<тема>`. Имеющиеся группы:
#     - **classic** - разные классические смайлики, например 👻🥶🍎,
#     - **colors** - однотонные цветные смайлики, например 🤍🔵🟥,
#     - **flags** - все флаги, например 🇷🇺🇨🇳🇯🇵,
#     - **food** - смайлики с едой и напитками, например 🥚🫐🍷,
#     - **hearts** - цветные сердечки, например 🤍💙❤️,
#     - **moon** - фазы луны, например 🌖🌗🌘;
# - **disp** - отображать ли прогресс создания картинки и результат.

# %%
# %%time

img = draw(image_filename='meme.jpg',
           save_image_name='meme',
           emoji_width=50,
           emoji_resolution=50,
           background_color=(255, 255, 255),
           emojis='😀 😎 👻 🤡 🎃 💀 🌚 🎓',
           emoji_dict_name='classic_white', 
           disp=True)

display(img)
# Out:
# Построение словаря:  100.0% (8/8)
# Исходная картинка: 564x735
# Из смайликов:      38x50
# Рисование: 100.0%
# Изображение в виде текста сохранено
# Сохранение изображения: 100.0%
# Изображение в png-формате сохранено
# <PIL.Image.Image image mode=RGBA size=2500x1900>
# CPU times: user 4.25 s, sys: 165 ms, total: 4.41 s
# Wall time: 7.41 s
